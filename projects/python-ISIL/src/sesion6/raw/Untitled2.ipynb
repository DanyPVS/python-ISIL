# %%
f = open("bebes1.csv","r")
print(f.read()[15:19])
# Out:
# 1990

# %%
f = open("bebes1.csv","r")
for line in f.readlines():
    l=(line.split(";"))
    print(l,rank)
# Out:
# ['POPULARIDAD EN 1990', '', '\n'] P
# ['Rank', 'name', 'Female name\n'] P
# ['1', 'Michael', 'Jessica\n'] P
# ['2', 'Christopher', 'Ashley\n'] P
# ['3', 'Matthew', 'Brittany\n'] P
# ['4', 'Joshua', 'Amanda\n'] P
# ['5', 'Daniel', 'Samantha\n'] P
# ['6', 'David', 'Sarah\n'] P
# ['7', 'Andrew', 'Stephanie\n'] P
# ['8', 'James', 'Jennifer\n'] P
# ['9', 'Justin', 'Elizabeth\n'] P
# ['10', 'Joseph', 'Lauren\n'] P
# ['11', 'Ryan', 'Megan\n'] P
# ['12', 'John', 'Emily\n'] P
# ['13', 'Robert', 'Nicole\n'] P
# ['14', 'Nicholas', 'Kayla\n'] P
# ['15', 'Anthony', 'Amber\n'] P
# ['16', 'William', 'Rachel\n'] P
# ['17', 'Jonathan', 'Courtney\n'] P
# ['18', 'Kyle', 'Danielle\n'] P
# ['19', 'Brandon', 'Heather\n'] P
# ['20', 'Jacob', 'Melissa\n'] P
# ['21', 'Tyler', 'Rebecca\n'] P
# ['22', 'Zachary', 'Michelle\n'] P
# ['23', 'Kevin', 'Tiffany\n'] P
# ['24', 'Eric', 'Chelsea\n'] P
# ['25', 'Steven', 'Christina\n'] P
# ['26', 'Thomas', 'Katherine\n'] P
# ['27', 'Brian', 'Alyssa\n'] P
# ...

# %%
import csv
f=open("da.csv","r")
f1=csv.reader(f)
for nombre,puntaje in f1:
    print(nombre,putaje)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-168649d8e376> in <module>()
#       2 f=open("da.csv","r")
#       3 f1=csv.reader(f)
# ----> 4 for nombre,puntaje in f1:
#       5     print(nombre,putaje)
#
# ValueError: too many values to unpack (expected 2)

# %%
import csv
f=open("da.csv","r")
f1=csv.reader(f)
for rank,name,nivel in f1:
    print(rank,name)
# Out:
# 1 juan
# 5 miguel

# %%
import csv
f=open("bebes1.csv","r")
f1=csv.reader(f)
for rank in f1:
    print(rank,name)
# Out:
# ['POPULARIDAD EN 1990;;'] miguel
# ['Rank;name;Female name'] miguel
# ['1;Michael;Jessica'] miguel
# ['2;Christopher;Ashley'] miguel
# ['3;Matthew;Brittany'] miguel
# ['4;Joshua;Amanda'] miguel
# ['5;Daniel;Samantha'] miguel
# ['6;David;Sarah'] miguel
# ['7;Andrew;Stephanie'] miguel
# ['8;James;Jennifer'] miguel
# ['9;Justin;Elizabeth'] miguel
# ['10;Joseph;Lauren'] miguel
# ['11;Ryan;Megan'] miguel
# ['12;John;Emily'] miguel
# ['13;Robert;Nicole'] miguel
# ['14;Nicholas;Kayla'] miguel
# ['15;Anthony;Amber'] miguel
# ['16;William;Rachel'] miguel
# ['17;Jonathan;Courtney'] miguel
# ['18;Kyle;Danielle'] miguel
# ['19;Brandon;Heather'] miguel
# ['20;Jacob;Melissa'] miguel
# ['21;Tyler;Rebecca'] miguel
# ['22;Zachary;Michelle'] miguel
# ['23;Kevin;Tiffany'] miguel
# ['24;Eric;Chelsea'] miguel
# ['25;Steven;Christina'] miguel
# ['26;Thomas;Katherine'] miguel
# ['27;Brian;Alyssa'] miguel
# ['28;Alexander;Jasmine'] miguel
# ['29;Jordan;Laura'] miguel
# ['30;Timothy;Hannah'] miguel
# ...
