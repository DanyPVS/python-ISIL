# %%
f=open("joel.csv","r")
for line in f.readlines():
    print(line.split(";"))
# Out:
# ['25,joel\n']
# ['46,dasq']

# %% [raw]
# import csv
# f=open("da.csv","r")
# f1
# for line in f:
#     a=(line.split(";"))
#     print(a)

# %%
import csv
f=open("raw/baby2008.csv","r")
f1=csv.reader(f)
for name in f1:
    print(name)
# Out:
# ['Social Security Online;Popular Baby Names;;']
# [';;;']
# ['Popular Baby Names;;;']
# [';;;']
# [';;;']
# [';Popular Names by Birth Year;;']
# [';;;']
# [';December 21', ' 2009;;']
# ['Background information;;;']
# [';;;']
# [';Popularity in 2008;;']
# ['\xa0 Select another year of birth?;;;']
# [';Rank;Male name;Female name']
# [';1;Jacob;Emma']
# [';2;Michael;Isabella']
# [';3;Ethan;Emily']
# [';4;Joshua;Madison']
# [';5;Daniel;Ava']
# [';6;Alexander;Olivia']
# [';7;Anthony;Sophia']
# [';8;William;Abigail']
# [';9;Christopher;Elizabeth']
# [';10;Matthew;Chloe']
# [';11;Jayden;Samantha']
# [';12;Andrew;Addison']
# [';13;Joseph;Natalie']
# [';14;David;Mia']
# [';15;Noah;Alexis']
# [';16;Aiden;Alyssa']
# [';17;James;Hannah']
# [';18;Ryan;Ashley']
# [';19;Logan;Ella']
# [';20;John;Sarah']
# [';21;Nathan;Grace']
# [';22;Elijah;Taylor']
# [';23;Christian;Brianna']
# [';24;Gabriel;Lily']
# [';25;Benjamin;Hailey']
# [';26;Jonathan;Anna']
# [';27;Tyler;Victoria']
# [';28;Samuel;Kayla']
# ...

# %%
    year=re.search(r'Popularity\sin\s(\d\d\d\d)', text)
    if not year:
        sys.stderr.write('Couldn\'t find the year!\r\n')
        sys.exit(1)
        year1=year.group(1)
        names.append(year1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e77dfe8aed9c> in <module>()
# ----> 1 year=re.search(r'Popularity\sin\s(\d\d\d\d)', text)
#       2 if not year:
#       3     sys.stderr.write('Couldn\'t find the year!\r\n')
#       4     sys.exit(1)
#       5     year1=year.group(1)
#
# NameError: name 're' is not defined
